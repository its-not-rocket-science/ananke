# %% [markdown]
# # RL Arena (PPO + Ananke bridge)

# %%
# !pip install stable-baselines3 gymnasium tensorboard numpy

# %%
# %load_ext tensorboard
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from arena_env import RLArenaEnv
env = Monitor(RLArenaEnv(seed=2026))
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log='runs/ppo')
model.learn(total_timesteps=100000)
model.save('rl-arena-ppo')

# %%
# %tensorboard --logdir runs
